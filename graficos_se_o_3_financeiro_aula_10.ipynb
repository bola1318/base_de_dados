# %% [markdown]
# <a href="https://colab.research.google.com/github/bola1318/base_de_dados/blob/main/graficos_se_o_3_financeiro_aula_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install yfinance
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.2/59.2 KB 2.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.8/112.8 KB 5.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 KB 2.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 29.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 KB 6.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 129.4/129.4 KB 2.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 199.2/199.2 KB 17.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: html5lib
#     Found existing installation: html5lib 1.0.1
#     Uninstalling html5lib-1.0.1:
#       Successfully uninstalled html5lib-1.0.1
#   Attempting uninstall: beautifulsoup4
#     Found existing installation: beautifulsoup4 4.9.3
#     Uninstalling beautifulsoup4-4.9.3:
# ...

# %%
import pandas as pd
import numpy as np    
from pandas_datareader import data     #SERÁ UTILIZADA PARA CARREGAR DADOS FINANCEIROS
import matplotlib.pyplot as plt  
import seaborn as sns           #graficos estaticos
import plotly.express as px    #liberar graficos interativos 
import yfinance as yf

# %% [markdown]
# ### **BUSCANDO UMA AÇÃO  site https://br.financas.yahoo.com/**

# %%
#gol_df = data.DataReader(name ='GOLL4.SA', data_source='yahoo', start ='2015-01-01')      #end = '2023-03-16'
gol_df = yf.download("GOLL4.SA", start='2015-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
gol_df
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99    901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85   1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21   2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55   1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27   1569500
# ...           ...    ...    ...    ...        ...       ...
# 2023-03-10   7.84   8.44   7.12   7.31       7.31  31176000
# 2023-03-13   7.09   7.66   7.01   7.20       7.20  13763200
# 2023-03-14   7.22   7.55   7.15   7.28       7.28  12877400
# 2023-03-15   7.20   7.38   6.88   7.17       7.17  12870900
# 2023-03-16   7.18   7.36   7.09   7.30       7.30  12014700
#
# [2040 rows x 6 columns]

# %%
gol_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2040 entries, 2015-01-02 to 2023-03-16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       2040 non-null   float64
#  1   High       2040 non-null   float64
#  2   Low        2040 non-null   float64
#  3   Close      2040 non-null   float64
#  4   Adj Close  2040 non-null   float64
#  5   Volume     2040 non-null   int64
# dtypes: float64(5), int64(1)
# memory usage: 111.6 KB

# %%
gol_df.head()  # 5 primeiros valores
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99   901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85  1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21  2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55  1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27  1569500

# %%
gol_df.tail() #5 ultimod valores
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2023-03-10  7.84  8.44  7.12   7.31       7.31  31176000
# 2023-03-13  7.09  7.66  7.01   7.20       7.20  13763200
# 2023-03-14  7.22  7.55  7.15   7.28       7.28  12877400
# 2023-03-15  7.20  7.38  6.88   7.17       7.17  12870900
# 2023-03-16  7.18  7.36  7.09   7.30       7.30  12014700

# %%
gol_df.describe()  #estatisticas
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean     15.137853    15.512284    14.742985    15.099225    15.099225
# std       9.312742     9.482679     9.133508     9.305366     9.305366
# min       1.160000     1.180000     1.130000     1.160000     1.160000
# 25%       7.770000     7.987500     7.600000     7.777500     7.777500
# 50%      13.700000    14.045000    13.325000    13.580000    13.580000
# 75%      20.955000    21.400000    20.385001    20.850000    20.850000
# max      43.669998    44.619999    41.310001    43.790001    43.790001
#
#              Volume
# count  2.040000e+03
# mean   5.858243e+06
# std    5.412464e+06
# min    0.000000e+00
# 25%    2.200175e+06
# 50%    4.298500e+06
# 75%    7.718750e+06
# max    6.724200e+07

# %%
gol_df[gol_df['Close'] >=11.86]   #mostra informações do dia que teve o preço de fechamento maior ou igual que 43.79
# Out:
#              Open   High    Low  Close  Adj Close    Volume
# Date
# 2015-01-02  14.97  15.20  14.61  14.99      14.99    901900
# 2015-01-05  14.90  15.01  14.41  14.85      14.85   1272500
# 2015-01-06  14.75  15.21  14.65  15.21      15.21   2183500
# 2015-01-07  15.15  15.33  14.55  14.55      14.55   1846900
# 2015-01-08  14.41  14.65  14.20  14.27      14.27   1569500
# ...           ...    ...    ...    ...        ...       ...
# 2022-06-06  13.89  13.92  13.44  13.48      13.48   6214800
# 2022-06-07  13.32  13.40  13.04  13.12      13.12   4490200
# 2022-06-08  13.04  13.28  12.88  12.93      12.93   7194700
# 2022-06-09  12.91  12.99  12.32  12.32      12.32   6413100
# 2022-08-25  11.41  12.15  11.31  11.92      11.92  10438200
#
# [1123 rows x 6 columns]

# %%
gol_df[gol_df['Close'] ==11.86]
# Out:
# Empty DataFrame
# Columns: [Open, High, Low, Close, Adj Close, Volume]
# Index: []

# %%
gol_df[(gol_df['Close'] >=1.86) & (gol_df['Close'] <=3.06) ]     #intervalo de tempo
# Out:
#             Open  High   Low  Close  Adj Close    Volume
# Date
# 2015-12-18  3.16  3.16  2.90   2.95       2.95   1793200
# 2015-12-21  2.95  2.99  2.79   2.80       2.80   1275200
# 2015-12-22  2.82  2.83  2.46   2.49       2.49   2890400
# 2015-12-23  2.54  2.58  2.36   2.46       2.46   2612400
# 2015-12-28  2.47  2.50  2.33   2.39       2.39   1577300
# ...          ...   ...   ...    ...        ...       ...
# 2016-06-16  2.47  2.49  2.40   2.45       2.45   1481200
# 2016-06-17  2.46  2.62  2.45   2.60       2.60   3071300
# 2016-06-20  2.69  2.75  2.62   2.68       2.68   4610300
# 2016-06-21  2.77  2.88  2.52   2.80       2.80  13130800
# 2016-06-22  2.92  3.17  2.85   2.98       2.98  13227600
#
# [93 rows x 6 columns]

# %%
gol_df.to_csv('gol.csv')

# %%
gol_df2 = pd.read_csv('/content/gol.csv') 
gol_df2
# Out:
#             Date   Open   High    Low  Close  Adj Close    Volume
# 0     2015-01-02  14.97  15.20  14.61  14.99      14.99    901900
# 1     2015-01-05  14.90  15.01  14.41  14.85      14.85   1272500
# 2     2015-01-06  14.75  15.21  14.65  15.21      15.21   2183500
# 3     2015-01-07  15.15  15.33  14.55  14.55      14.55   1846900
# 4     2015-01-08  14.41  14.65  14.20  14.27      14.27   1569500
# ...          ...    ...    ...    ...    ...        ...       ...
# 2035  2023-03-10   7.84   8.44   7.12   7.31       7.31  31176000
# 2036  2023-03-13   7.09   7.66   7.01   7.20       7.20  13763200
# 2037  2023-03-14   7.22   7.55   7.15   7.28       7.28  12877400
# 2038  2023-03-15   7.20   7.38   6.88   7.17       7.17  12870900
# 2039  2023-03-16   7.18   7.36   7.09   7.30       7.30  12014700
#
# [2040 rows x 7 columns]

# %%
acoes = ['GOLL4.SA', 'CVCB3.SA', 'WEGE3.SA', 'MGLU3.SA', 'TOTS3.SA', 'BOVA11.SA']

# %%
acoes_df = pd.DataFrame()
for acao in acoes:
  #acoes_df[acao] = data.DataReader(acao, data_source= 'yahoo', start='2015-01-01')
  acoes_df[acao] = yf.download(acao, start='2015-01-01')['Close']
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
acoes_df
# Out:
#             GOLL4.SA  CVCB3.SA   WEGE3.SA  MGLU3.SA   TOTS3.SA   BOVA11.SA
# Date
# 2015-01-02     14.99     15.20   5.923076  0.232812  11.910702   47.259998
# 2015-01-05     14.85     15.00   5.963461  0.237187  11.544731   46.320000
# 2015-01-06     15.21     14.80   5.875000  0.234062  10.822770   46.580002
# 2015-01-07     14.55     14.67   5.807692  0.241875  10.746248   48.150002
# 2015-01-08     14.27     14.15   5.905769  0.240000  10.995774   48.509998
# ...              ...       ...        ...       ...        ...         ...
# 2023-03-10      7.31      3.43  39.540001  3.400000  27.400000  100.209999
# 2023-03-13      7.20      3.55  39.790001  3.720000  28.049999   99.779999
# 2023-03-14      7.28      3.27  40.259998  3.730000  28.540001   99.580002
# 2023-03-15      7.17      3.07  40.070000  3.810000  28.830000   99.389999
# 2023-03-16      7.30      3.32  40.299999  3.890000  28.950001  100.000000
#
# [2040 rows x 6 columns]

# %%
acoes_df = acoes_df.rename(columns={'GOLL4.SA' : 'GOL', 'CVCB3.SA' : 'CVC', 'WEGE3.SA' : 'WEGE', 'MGLU3.SA' : 'MGLU', 'TOTS3.SA' : 'TOTS', 'BOVA11.SA' : 'BOVA'})

# %%
acoes_df.head()
# Out:
#               GOL    CVC      WEGE      MGLU       TOTS       BOVA
# Date
# 2015-01-02  14.99  15.20  5.923076  0.232812  11.910702  47.259998
# 2015-01-05  14.85  15.00  5.963461  0.237187  11.544731  46.320000
# 2015-01-06  15.21  14.80  5.875000  0.234062  10.822770  46.580002
# 2015-01-07  14.55  14.67  5.807692  0.241875  10.746248  48.150002
# 2015-01-08  14.27  14.15  5.905769  0.240000  10.995774  48.509998

# %%
acoes_df.isnull().sum()  #verifica valores nulos e soma para mostrar quantos tem
# Out:
# GOL     0
# CVC     0
# WEGE    0
# MGLU    0
# TOTS    0
# BOVA    0
# dtype: int64

# %%
acoes_df.shape
# Out:
# (2040, 6)

# %%
acoes_df.dropna(inplace=True) #limpa valores nulos

# %%
acoes_df
# Out:
#               GOL    CVC       WEGE      MGLU       TOTS        BOVA
# Date
# 2015-01-02  14.99  15.20   5.923076  0.232812  11.910702   47.259998
# 2015-01-05  14.85  15.00   5.963461  0.237187  11.544731   46.320000
# 2015-01-06  15.21  14.80   5.875000  0.234062  10.822770   46.580002
# 2015-01-07  14.55  14.67   5.807692  0.241875  10.746248   48.150002
# 2015-01-08  14.27  14.15   5.905769  0.240000  10.995774   48.509998
# ...           ...    ...        ...       ...        ...         ...
# 2023-03-10   7.31   3.43  39.540001  3.400000  27.400000  100.209999
# 2023-03-13   7.20   3.55  39.790001  3.720000  28.049999   99.779999
# 2023-03-14   7.28   3.27  40.259998  3.730000  28.540001   99.580002
# 2023-03-15   7.17   3.07  40.070000  3.810000  28.830000   99.389999
# 2023-03-16   7.30   3.32  40.299999  3.890000  28.950001  100.000000
#
# [2040 rows x 6 columns]

# %%
acoes_df.to_csv('acoes.csv')

# %%
acoes_df = pd.read_csv('acoes.csv')
acoes_df
# Out:
#             Date    GOL    CVC       WEGE      MGLU       TOTS        BOVA
# 0     2015-01-02  14.99  15.20   5.923076  0.232812  11.910702   47.259998
# 1     2015-01-05  14.85  15.00   5.963461  0.237187  11.544731   46.320000
# 2     2015-01-06  15.21  14.80   5.875000  0.234062  10.822770   46.580002
# 3     2015-01-07  14.55  14.67   5.807692  0.241875  10.746248   48.150002
# 4     2015-01-08  14.27  14.15   5.905769  0.240000  10.995774   48.509998
# ...          ...    ...    ...        ...       ...        ...         ...
# 2035  2023-03-10   7.31   3.43  39.540001  3.400000  27.400000  100.209999
# 2036  2023-03-13   7.20   3.55  39.790001  3.720000  28.049999   99.779999
# 2037  2023-03-14   7.28   3.27  40.259998  3.730000  28.540001   99.580002
# 2038  2023-03-15   7.17   3.07  40.070000  3.810000  28.830000   99.389999
# 2039  2023-03-16   7.30   3.32  40.299999  3.890000  28.950001  100.000000
#
# [2040 rows x 7 columns]

# %%
acoes_df.columns
# Out:
# Index(['Date', 'GOL', 'CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
acoes_df.columns[1:]
# Out:
# Index(['GOL', 'CVC', 'WEGE', 'MGLU', 'TOTS', 'BOVA'], dtype='object')

# %%
acoes_df.describe()
# Out:
#                GOL          CVC         WEGE         MGLU         TOTS  \
# count  2040.000000  2040.000000  2040.000000  2040.000000  2040.000000
# mean     15.099225    27.427998    17.495873     6.677407    18.163828
# std       9.305366    16.476410    12.776904     7.553131     9.427226
# min       1.160000     2.790000     4.942307     0.030585     7.156402
# 25%       7.777500    14.583191     6.791345     0.465136    10.095817
# 50%      13.580000    21.515000     9.432500     3.870937    12.747446
# 75%      20.850000    42.400002    31.250000     9.512500    27.612501
# max      43.790001    64.800003    46.105000    27.450001    40.599998
#
#               BOVA
# count  2040.000000
# mean     82.425506
# std      23.930015
# min      36.450001
# 25%      60.597501
# 50%      83.645000
# 75%     103.607498
# max     125.750000

# %% [markdown]
# ### **GERAR GRAFICOS**
# mostra os valores mais comuns

# %%
sns.histplot(acoes_df['GOL']);

# %%
sns.histplot(acoes_df['GOL'], bins=5);    #dividir em 5 faixa de valores

# %%
sns.histplot(acoes_df['GOL'], bins=10);

# %%
len(acoes_df.columns)
# Out:
# 7

# %%
np.arange(1, len(acoes_df.columns))
# Out:
# array([1, 2, 3, 4, 5, 6])

# %% [markdown]
# **Definir uma figura**

# %%
plt.figure(figsize=(10,50))    #FIGSIZE TAMANHO DO GRAFICO   
i = 1
for i in np.arange(1, len(acoes_df.columns)):
    plt.subplot(7, 1, i + 1)   #uma tabela com 7 linhas e uma coluna, cada linha um grafico    i+1 é um contador para mostrar 
    sns.histplot(acoes_df[acoes_df.columns[i]])
    plt.title(acoes_df.columns[i])
