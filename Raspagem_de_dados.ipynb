# %% [markdown]
# <a href="https://colab.research.google.com/github/bola1318/base_de_dados/blob/main/Raspagem_de_dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #importando bibliotecas

# %%
import pandas as pd
import requests
from google.colab import data_table
data_table.enable_dataframe_formatter()

# %% [markdown]
# #informacoes de navegador

# %%
#Informações para fingir ser um navegador
header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

#A url q vc quer acessar

url_link1="https://www.soccerstats.com/matches.asp?matchday=101&listing=1"
url_link2="https://www.soccerstats.com/matches.asp?matchday=101&listing=2"

#juntamos tudo com o requests

r1=requests.get(url_link1,headers=header)
r2=requests.get(url_link2,headers=header)


#finalmente usamos a função a função read_html do pandas

df1=pd.read_html(r1.text)
df2=pd.read_html(r2.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-eea6e6c1c7e5> in <module>
#      12 #juntamos tudo com o requests
#      13
# ---> 14 r1=requests.get(url_link1,headers=header)
#      15 r2=requests.get(url_link2,headers=header)
#      16
#
# NameError: name 'requests' is not defined

# %%
#len(df1)

# %%
#df1[6]

# %%
#len(df2)

# %%
#df2[6]

# %%
# GP: number of matches played
# W%: percentage of matches won
# FTS: % Failed to score
# CS: % Clean sheet
# BTS: % of matches where both teams scored 
# TG: Average total goals scored + conceded per match
# GF: goals scored per match 
# GA: goals conceded per match
# 1.5+: % of matches over 1.5 goals (scored + conceded)
# 2.5+: % of matches over 2.5 goals (scored + conceded) 
# 3.5+: % of matches over 3.5 goals (scored + conceded)
# PPG: Points per game

# %%
jogos_today1 = df1[6]
jogos_today1 = jogos_today1[['Country','2.5+','1.5+','GA','GF','TG','PPG','Unnamed: 9','Unnamed: 10','Unnamed: 11','PPG.1','TG.1','GF.1','GA.1','1.5+.1','2.5+.1']]
jogos_today1.columns = ['País','Over25_H','Over15_H','GolsSofridos_H','GolsMarcados_H','MediaGols_H','PPG_H','Home','Hora','Away','PPG_A','MediaGols_A','GolsMarcados_A','GolsSofridos_A','Over15_A','Over25_A']

# %%
jogos_today2 = df2[6]
jogos_today2 = jogos_today2[['BTS','W%','BTS.1','W%.1']]
jogos_today2.columns = ['BTTS_H','Vitorias_H','BTTS_A','Vitorias_A']

# %%
jogos_today = pd.concat([jogos_today1,jogos_today2],axis=1)
jogos_today = jogos_today[['País','Hora','Home','Away','Vitorias_H','Vitorias_A','Over15_H','Over25_H','Over15_A','Over25_A','BTTS_H','BTTS_A','GolsMarcados_H','GolsSofridos_H','GolsMarcados_A','GolsSofridos_A','MediaGols_H','MediaGols_A','PPG_H','PPG_A']]

# %%
jogos_today = jogos_today.sort_values('Hora')
jogos_today['Hora'] = pd.to_datetime(jogos_today['Hora']) - pd.DateOffset(hours=4)
jogos_today['Hora'] = pd.to_datetime(jogos_today['Hora'], format='%H:%M').dt.time
jogos_today = jogos_today.dropna()

# %% [markdown]
# # Resetando o Index

# %%
jogos_today.reset_index(inplace=True, drop=True)
jogos_today.index = jogos_today.index.set_names(['Nº'])
jogos_today = jogos_today.rename(index=lambda x: x + 1)

# %% [markdown]
# # Exportando para o Excel

# %%
#jogos_today.to_excel("Jogos de Hoje.xlsx")

# %%
df = jogos_today
df
# Out:
#    País      Hora             Home             Away Vitorias_H Vitorias_A  \
# Nº
# 1   MAL  13:30:00           Melita           Qrendi        62%        12%
# 2   SPA  14:00:00        Levante W         Alaves W        50%         0%
# 3   SPA  14:00:00         Huelva W        Sevilla W        33%        33%
# 4   GER  14:00:00           Altona  Eimsbutteler TV        47%        67%
# 5   SPA  14:00:00     Villarreal B      Real Oviedo        31%        23%
# 6   SPA  14:00:00            Eibar             Lugo        46%        23%
# 7   ENG  15:00:00    Southampton W   Coventry Utd W        57%         0%
# 8   BRA  15:00:00       America MG    Internacional        38%        50%
# 9   BRA  15:00:00     Athletico PR            Goias        41%        29%
# 10  CHI  15:30:00     S. Wanderers    CD Santa Cruz        29%        29%
# 11  ENG  15:30:00   Sevenoaks Town     Burgess Hill        38%        33%
# 12  NOR  15:45:00    Sion Swifts W        Lisburn W        50%        25%
# 13  NOR  15:45:00       Linfield W      Crusaders W        44%        56%
# 14  NOR  15:45:00     Derry City W     Mid-Ulster W         0%         6%
# 15  NOR  15:45:00   Cliftonville W      Glentoran W        94%        75%
# 16  ENG  15:45:00          Burnley        Rotherham        50%        29%
# 17  ENG  15:45:00      Havant & W.    Ebbsfleet Utd        71%        79%
# 18  ENG  15:45:00     Cardiff City          Watford        35%        41%
# 19  ENG  15:45:00     Norwich City       QP Rangers        44%        53%
# 20  ENG  15:45:00  Birmingham City         Millwall        35%        47%
# 21  ENG  15:45:00   Wigan Athletic       Stoke City        29%        29%
# 22  ENG  15:45:00     Huddersfield       Sunderland        25%        29%
# 23  SPA  16:00:00       Valencia W     Real Betis W        33%        17%
# 24  SCO  16:00:00           Rothes      Banks O Dee        27%        50%
# 25  SCO  16:00:00     Nairn County     Wick Academy         8%        33%
# 26  SCO  16:00:00            Keith   Buckie Thistle        29%        83%
# 27  SCO  16:00:00           Huntly      Fraserburgh        31%        67%
# 28  SCO  16:00:00      Deveronvale   Formartine Utd        14%        67%
# 29  SCO  16:00:00    Clachnacuddin    Strathspey T.        23%         0%
# 30  MAL  16:00:00          Tarxien      St. Andrews        50%        38%
# 31  MAL  16:00:00       Marsaskala           Attard        12%        38%
# 32  SPA  16:00:00         Mirandes         Tenerife         8%        23%
# 33  GUA  17:30:00   Coban Imperial        Municipal        53%        33%
# 34  BRA  18:00:00      Atletico GO           Santos        24%        32%
# 35  BRA  18:00:00             Avai       Bragantino        21%        29%
# 36  BRA  18:00:00        Juventude         Coritiba         9%        29%
#
#    Over15_H Over25_H Over15_A Over25_A BTTS_H BTTS_A  GolsMarcados_H  \
# Nº
# 1       75%      62%      75%      38%    50%     0%            2.50
# 2      100%      67%      83%      67%    83%    67%            1.83
# 3       67%      50%     100%      50%    17%    33%            0.50
# 4       93%      60%      93%      73%    60%    60%            1.73
# 5       77%      62%      31%      15%    54%    31%            1.31
# 6       69%      46%      69%      46%    46%    62%            1.23
# 7       57%      29%      71%      71%    43%    29%            1.14
# 8       59%      38%      71%      47%    41%    50%            0.97
# 9       65%      41%      65%      41%    47%    59%            1.21
# 10      74%      42%      71%      42%    55%    48%            1.13
# 11      38%      38%      44%      22%    38%    33%            1.13
# 12     100%      75%      88%      69%    62%    44%            2.31
# 13      94%      81%      81%      75%    56%    56%            2.13
# 14      88%      62%     100%      75%    12%    50%            0.13
# 15     100%      94%      88%      81%    38%    44%            4.00
# 16      78%      33%      76%      41%    67%    41%            1.78
# 17      86%      64%      93%      71%    71%    64%            2.36
# 18      53%      29%      76%      53%    29%    53%            0.76
# 19      72%      50%      71%      53%    61%    53%            1.44
# 20      65%      29%      88%      41%    41%    41%            1.06
# 21      71%      47%      76%      41%    65%    41%            1.00
# 22      62%      50%      71%      53%    50%    53%            1.06
# 23      67%       0%     100%      83%    33%    50%            0.83
# 24      87%      67%     100%      50%    60%    58%            1.67
# 25     100%      83%      83%      67%    75%    50%            1.25
# 26      86%      64%      92%      75%    50%    50%            1.29
# 27      77%      54%     100%      83%    54%    42%            1.31
# 28      86%      71%      92%      75%    50%    75%            1.14
# 29      85%      85%     100%      93%    69%    57%            1.23
# 30     100%      62%      75%      25%    88%    38%            1.75
# 31     100%      88%      75%      75%    75%    75%            1.50
# 32      69%      38%      77%      31%    54%    54%            0.85
# 33      73%      67%      67%      47%    67%    53%            1.73
# 34      79%      41%      59%      44%    62%    47%            1.00
# 35      74%      53%      79%      50%    53%    59%            0.82
# 36      74%      50%      74%      47%    56%    47%            0.76
#
#     GolsSofridos_H  GolsMarcados_A  GolsSofridos_A  MediaGols_H  MediaGols_A  \
# Nº
# 1             1.25            0.38            1.75         3.75         2.13
# 2             1.33            0.67            3.33         3.17         4.00
# 3             1.83            1.67            1.50         2.33         3.17
# 4             1.40            2.60            0.87         3.13         3.47
# 5             1.38            0.54            0.85         2.69         1.38
# 6             0.92            1.08            1.31         2.15         2.38
# 7             0.86            0.57            3.43         2.00         4.00
# 8             1.06            1.53            0.88         2.03         2.41
# 9             1.26            1.09            1.26         2.47         2.35
# 10            1.19            1.10            1.19         2.32         2.29
# 11            1.13            0.89            0.89         2.25         1.78
# 12            1.44            1.06            2.69         3.75         3.75
# 13            1.88            2.44            1.38         4.00         3.81
# 14            4.25            0.75            4.00         4.38         4.75
# 15            0.50            4.00            0.69         4.50         4.69
# 16            0.89            1.18            1.18         2.67         2.35
# 17            1.29            2.64            0.86         3.64         3.50
# 18            1.12            1.41            1.18         1.88         2.59
# 19            1.11            1.47            1.12         2.56         2.59
# 20            0.88            1.29            1.18         1.94         2.47
# 21            1.47            1.06            1.35         2.47         2.41
# 22            1.38            1.29            1.24         2.44         2.53
# 23            0.67            1.00            2.17         1.50         3.17
# 24            2.20            2.75            1.00         3.87         3.75
# 25            2.83            1.00            2.17         4.08         3.17
# 26            2.50            3.58            0.75         3.79         4.33
# 27            1.54            3.50            0.67         2.85         4.17
# 28            2.64            2.33            1.08         3.79         3.42
# 29            2.54            0.86            5.07         3.77         5.93
# 30            1.38            1.13            1.50         3.13         2.63
# 31            2.63            1.38            2.13         4.13         3.50
# 32            1.38            1.00            1.15         2.23         2.15
# 33            1.33            1.53            1.27         3.07         2.80
# 34            1.50            1.18            0.97         2.50         2.15
# 35            1.65            1.35            1.38         2.47         2.74
# 36            1.79            1.00            1.65         2.56         2.65
#
#     PPG_H  PPG_A
# Nº
# 1    2.00   0.50
# 2    1.83   0.17
# 3    1.17   1.17
# 4    1.67   2.20
# 5    1.31   1.00
# 6    1.69   1.00
# 7    2.00   0.00
# 8    1.35   1.88
# 9    1.50   1.26
# 10   1.26   1.16
# 11   1.25   1.22
# 12   1.63   0.88
# 13   1.50   1.81
# 14   0.19   0.25
# 15   2.81   2.44
# 16   1.94   1.29
# 17   2.36   2.57
# 18   1.24   1.53
# 19   1.56   1.76
# 20   1.35   1.53
# 21   1.12   1.12
# 22   0.94   1.24
# 23   1.50   0.67
# 24   1.07   1.92
# 25   0.67   1.08
# 26   1.00   2.58
# 27   1.15   2.17
# 28   0.64   2.17
# 29   0.77   0.14
# 30   1.75   1.38
# 31   0.38   1.13
# 32   0.69   1.08
# 33   1.80   1.27
# 34   0.97   1.26
# 35   0.82   1.21
# 36   0.62   1.03

# %%
flt = (df.GolsMarcados_H > 1) & (df.GolsSofridos_H > 1) & (df.GolsMarcados_A > 1) & (df.GolsSofridos_A > 1) & (df.MediaGols_H > 1) & (df.MediaGols_A > 1)
df1 = df[flt]
#df1

# %%
#df.info()

# %% [markdown]
# excluindo %

# %%
filtro=df
filtro['Vitorias_H'] = filtro['Vitorias_H'].apply(lambda x: str(x).replace("%",""))
filtro['Vitorias_A'] = filtro['Vitorias_A'].apply(lambda x: str(x).replace("%",""))
filtro['Over15_H'] = filtro['Over15_H'].apply(lambda x: str(x).replace("%",""))
filtro['Over25_H'] = filtro['Over25_H'].apply(lambda x: str(x).replace("%",""))
filtro['Over15_A'] = filtro['Over15_A'].apply(lambda x: str(x).replace("%",""))
filtro['Over25_A'] = filtro['Over25_A'].apply(lambda x: str(x).replace("%",""))
filtro['BTTS_H'] = filtro['BTTS_H'].apply(lambda x: str(x).replace("%",""))
filtro['BTTS_A'] = filtro['BTTS_A'].apply(lambda x: str(x).replace("%",""))

# %% [markdown]
# convertendo par float

# %%
filtro['Vitorias_H'] = filtro['Vitorias_H'].astype(float, errors = 'raise')
filtro['Vitorias_A'] = filtro['Vitorias_A'].astype(float, errors = 'raise')
filtro['Over15_H'] = filtro['Over15_H'].astype(float, errors = 'raise')
filtro['Over25_H'] = filtro['Over25_H'].astype(float, errors = 'raise')
filtro['Over15_A'] = filtro['Over15_A'].astype(float, errors = 'raise')
filtro['Over25_A'] = filtro['Over25_A'].astype(float, errors = 'raise')
filtro['BTTS_H'] = filtro['BTTS_H'].astype(float, errors = 'raise')
filtro['BTTS_A'] = filtro['BTTS_A'].astype(float, errors = 'raise')

# %%
#filtro

# %%
Tips = (filtro.Vitorias_H  >= 60) &(filtro.Over15_H >=60)&(filtro.GolsMarcados_H>1)#&(filtro.GolsSofridos_H>=1)&(filtro.GolsSofridos_A>=1)
df3 = filtro[Tips]
df3
# Out:
#    País      Hora             Home            Away  Vitorias_H  Vitorias_A  \
# Nº
# 2   PAR  20:15:00         Nacional         Olimpia        60.0        60.0
# 12  MEX  23:05:00       CF America   Santos Laguna        71.0        57.0
# 15  CHI  04:30:00   Qingdao Jonoon    Hebei Kungfu        65.0        55.0
# 18  MYA  06:00:00          Myawady     Sagaing Utd        60.0        30.0
# 39  CHI  12:30:00       Magallanes      S. Morning        69.0        24.0
# 42  CYP  13:00:00             Aris     Karmiotissa       100.0         0.0
# 51  KUW  14:40:00            Kazma        Al Nasar        67.0        33.0
# 65  ISR  19:00:00  Hapoel Herzliya      Bnei Eilat       100.0         0.0
# 68  AZE  19:00:00           Neftci          Sebail        83.0        17.0
# 72  ISR  19:00:00  Hapoel Migdal H  Hapoel Raanana       100.0       100.0
#
#     Over15_H  Over25_H  Over15_A  Over25_A  BTTS_H  BTTS_A  GolsMarcados_H  \
# Nº
# 2       80.0      50.0     100.0      50.0    60.0    60.0            1.50
# 12      79.0      71.0      86.0      57.0    43.0    57.0            2.21
# 15      80.0      50.0      75.0      45.0    60.0    35.0            1.95
# 18      70.0      40.0      80.0      80.0    30.0    50.0            1.60
# 39      65.0      42.0      76.0      48.0    42.0    72.0            1.65
# 42      67.0      67.0     100.0      67.0    33.0    33.0            2.67
# 51     100.0      67.0     100.0      67.0    67.0   100.0            2.33
# 65     100.0     100.0     100.0     100.0   100.0   100.0            3.00
# 68      83.0      83.0      67.0      50.0    67.0    67.0            2.33
# 72     100.0     100.0     100.0       0.0   100.0     0.0            2.00
#
#     GolsSofridos_H  GolsMarcados_A  GolsSofridos_A  MediaGols_H  MediaGols_A  \
# Nº
# 2             0.80            1.90            1.10         2.30         3.00
# 12            0.86            2.14            1.29         3.07         3.43
# 15            0.80            1.40            0.85         2.75         2.25
# 18            1.00            0.90            3.00         2.60         3.90
# 39            0.73            1.08            1.48         2.38         2.56
# 42            0.33            0.33            2.67         3.00         3.00
# 51            0.67            1.67            1.67         3.00         3.33
# 65            1.00            2.00            2.00         4.00         4.00
# 68            1.00            1.17            1.33         3.33         2.50
# 72            1.00            2.00            0.00         3.00         2.00
#
#     PPG_H  PPG_A
# Nº
# 2    2.10   2.00
# 12   2.21   1.86
# 15   2.15   1.85
# 18   1.80   0.90
# 39   2.23   1.04
# 42   3.00   0.00
# 51   2.33   1.33
# 65   3.00   1.00
# 68   2.50   0.83
# 72   3.00   3.00
